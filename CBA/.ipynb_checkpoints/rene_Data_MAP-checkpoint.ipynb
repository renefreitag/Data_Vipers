# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# import seaborn as sns
# sns.set()
# sns.set_style("white")
# sns.set_palette("GnBu_d")

# also import these "new" libraries 
# Note: you may have to download an add them to your environment (using e.g. 'conda install -c conda-forge folium')

import folium
from folium import plugins
from folium.plugins import HeatMap
from datetime import datetime #for working with times objects
from datetime import timedelta #for working with times objects
import math
import random
from pathlib import Path

import geopy
from geopy.geocoders import GoogleV3
from geopy.distance import geodesic

# %%
# df = pd.read_csv("../boston_2016.csv")
df = pd.read_csv("../boston_2016_distance_duration_speed.csv")

df["start_time"] = pd.to_datetime(df["start_time"],format="%Y-%m-%d %H:%M:%S") # FORMAT %Y-%m-%d %H:%M:%S beachte - und :
df["end_time"] = pd.to_datetime(df["end_time"],format="%Y-%m-%d %H:%M:%S")

# %%
print(len(df))
# Out:
# 1236203

# %%
# # 2. Create Figure
# p = figure(plot_width = 600, plot_height = 400, title = 'My First Plot')
# # 3. Add Glyphs
# x = [1, 2, 3, 4, 5]
# y = [10, 20, 40, 80, 160]
# p.circle(x, y, color = 'red', alpha = 0.5, size = 15)
# # 4. Show the plot
# output_notebook()
# show(p)

# %%
import math
from ast import literal_eval
def merc(Coords):
    Coordinates = literal_eval(Coords)
    lat = Coordinates[0]
    lon = Coordinates[1]
    
    r_major = 6378137.000
    x = r_major * math.radians(lon)
    scale = x/lon
    y = 180.0/math.pi * math.log(math.tan(math.pi/4.0 + 
        lat * (math.pi/180.0)/2.0)) * scale
    return (x, y)

# %%
top_left = '(42.41568810349132, -71.15337356574248)'
bottom_right = '(42.308814794642046, -70.9677292096557)'

# %%
merc(top_left)
# Out:
# (-7920757.313562025, 5223452.331299398)

# %%
merc(bottom_right)
# Out:
# (-7900091.4783737995, 5207351.240481618)

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.tile_providers import CARTODBPOSITRON, get_provider

tile_provider = get_provider(CARTODBPOSITRON)

p = figure(x_range=(-7920757.313562025, -7900091.4783737995), y_range=(5223452.331299398, 5207351.240481618),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(tile_provider)

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1044">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b008208b-7968-461b-a7c5-284807400a0a" data-root-id="1003"></div>

# %%
df_stations= pd.read_csv("../all_station_id_with_amounts.csv")

# %%
df_stations['coordinates'] = list(zip(df_stations["start_station_latitude"],df_stations["start_station_longitude"]))

# %%
df_stations.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  start_station_id  \
# 0           0          4748                 1
# 1           1         26681                 3
# 2           2         97049                 4
# 3           3        161457                 5
# 4           4        103358                 6
#
#                    start_station_name  start_station_latitude  \
# 0               18 Dorrance Warehouse               42.387151
# 1              Colleges of the Fenway               42.340021
# 2         Tremont St. at Berkeley St.               42.345392
# 3  Northeastern U / North Parking Lot               42.341814
# 4            Cambridge St. at Joy St.               42.361174
#
#    start_station_longitude  amout_of_trips_per_station  \
# 0               -71.075978                          78
# 1               -71.100812                        4690
# 2               -71.069616                        9005
# 3               -71.090179                        7090
# 4               -71.065142                       11713
#
#                coordinates
# 0  (42.387151, -71.075978)
# 1  (42.340021, -71.100812)
# 2  (42.345392, -71.069616)
# 3  (42.341814, -71.090179)
# 4  (42.361174, -71.065142)

# %%
def makestr(x):
    return (str(x))

# %%
df_stations['str_coords'] = df_stations['coordinates'].apply(lambda x: makestr(x))

# %%
df_stations['coords_x'] = df_stations['str_coords'].apply(lambda x: merc(x)[0])
df_stations['coords_y'] = df_stations['str_coords'].apply(lambda x: merc(x)[1])

# %%
df_stations.head(1)
# Out:
#    Unnamed: 0  Unnamed: 0.1  start_station_id     start_station_name  \
# 0           0          4748                 1  18 Dorrance Warehouse
#
#    start_station_latitude  start_station_longitude  \
# 0               42.387151               -71.075978
#
#    amout_of_trips_per_station              coordinates  \
# 0                          78  (42.387151, -71.075978)
#
#                 str_coords      coords_x      coords_y
# 0  (42.387151, -71.075978) -7.912142e+06  5.219150e+06

# %%
p = figure(x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(tile_provider)
p.circle(x = df_stations['coords_x'],
         y = df_stations['coords_y'])
output_notebook()
# show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1309">Loading BokehJS ...</span>
#     </div>

# %%
df_stations.drop(['Unnamed: 0.1','Unnamed: 0','start_station_id','start_station_name','start_station_latitude','start_station_longitude','coordinates','str_coords'], axis=1, inplace=True)

# %%
df_stations.head(1)
# Out:
#    amout_of_trips_per_station      coords_x      coords_y
# 0                          78 -7.912142e+06  5.219150e+06

# %%
Merged = df_stations

# %%
Merged['circle_sizes'] = Merged['amout_of_trips_per_station'] / 1000

# %%
# range bounds supplied in web mercator coordinates
p = figure(x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(tile_provider)
p.circle(x=Merged['coords_x'],
         y=Merged['coords_y'], 
         size=Merged['circle_sizes'],
         line_color="#FF0000", 
         fill_color="#FF0000",
         fill_alpha=0.05)
    
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2526">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="aeb8b3f8-d190-444b-b78e-4e52447c80d6" data-root-id="2479"></div>
